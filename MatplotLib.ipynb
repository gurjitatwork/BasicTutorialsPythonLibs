# %%
import matplotlib.pyplot as plt

# %%
k=[1,1.2,4,5,7.7,8,6]

# %%
plt.plot(k,'ro') # r-, r^, r 
plt.ylabel("y axis")
plt.axis([0,10,0,10]) # range of x-axis, y-axis
plt.show()

# %%
plt.plot(k,'r', [5,5,8,9,7,9],'b')  # two curves
plt.show()
